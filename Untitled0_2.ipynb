# %% [markdown]
# <a href="https://colab.research.google.com/github/christianeiken-coder/Ai-Medical-Physics/blob/main/Untitled0_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Download our data again:
# !gdown 1TItTaso19GFTPdDnynVnqJvHsCm_RGlI
# !rm -rf ./sample_data/
# !unzip -qq Clean_LiTS.zip
# !rm ./Clean_LiTS.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1TItTaso19GFTPdDnynVnqJvHsCm_RGlI
# From (redirected): https://drive.google.com/uc?id=1TItTaso19GFTPdDnynVnqJvHsCm_RGlI&confirm=t&uuid=6f0cd431-7405-4b39-a17a-5d88775de04c
# To: /content/Clean_LiTS.zip
# 100% 2.56G/2.56G [00:37<00:00, 68.6MB/s]

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader, WeightedRandomSampler
import torchvision.transforms.functional as ttf
import pandas as pd
import torchvision.transforms as T
import torch
from PIL import Image
import numpy as np


class LiTS_Dataset(Dataset):

    def __init__(self, csv: str, mode: str, transform=None):

        self.csv = csv
        self.transform = transform
        self.data = pd.read_csv(self.csv)
        self.mode = mode
        assert mode in ["train", "val", "test"]

    def __len__(self):

        return len(self.data)

    def __getitem__(self, idx):

        file = self.data.loc[idx, "filename"]
        # ACHTUNG: hier Image.open statt PIL.Image.open
        with Image.open(f"./Clean_LiTS/{self.mode}/{file}") as f:
            f = f.convert("L")
            image = ttf.pil_to_tensor(f)   # [1,H,W]

        image = image.to(dtype=torch.float32)
        image -= torch.min(image)
        maxv = torch.max(image)
        if maxv > 0:
            image /= maxv  # in [0,1]

        # --- Multi-Label Targets: [liver_visible, lesion_visible] ---
        liver_visible  = int(self.data.loc[idx, "liver_visible"])
        lesion_visible = int(self.data.loc[idx, "lesion_visible"])

        # multi-label: [liver, tumor]
        target = torch.tensor([liver_visible, lesion_visible],
                              dtype=torch.float32)

        if self.transform:
            image = self.transform(image)

        return image, target

train_tf = T.Compose([
    T.RandomRotation(10),
    T.RandomHorizontalFlip(),
    T.RandomVerticalFlip(),
    T.RandomAffine(10, scale=(0.95, 1.05)),
])

train_ds = LiTS_Dataset("/content/Clean_LiTS/train_classes.csv", mode="train", transform=train_tf)
val_ds   = LiTS_Dataset("/content/Clean_LiTS/val_classes.csv",   mode="val")
test_ds  = LiTS_Dataset("/content/Clean_LiTS/test_classes.csv",  mode="test")

# --------------------------
#   3) LABELS EXTRAHIEREN (0/1/2 für Sampler)
# --------------------------
labels = []
for idx, row in train_ds.data.iterrows():
    liver_visible  = int(row["liver_visible"])
    lesion_visible = int(row["lesion_visible"])

    if liver_visible == 0:
        labels.append(0)      # keine Leber
    elif lesion_visible == 0:
        labels.append(1)      # Leber, kein Tumor
    else:
        labels.append(2)      # Leber + Tumor

labels = np.array(labels)

# Klassenhäufigkeiten ausgeben
class_counts = np.bincount(labels)
print("Klassenhäufigkeiten:", class_counts)


# --------------------------
#   4) KLASSEN-GEWICHTE (sqrt-Version)
# --------------------------
class_weights = 1.0 / np.sqrt(class_counts)
class_weights = class_weights / class_weights.sum()  # normalisieren

print("Class Weights:", class_weights)

# --------------------------
#   5) SAMPLE-GEWICHTE
# --------------------------
sample_weights = class_weights[labels]
sample_weights = torch.tensor(sample_weights, dtype=torch.float32)

# --------------------------
#   6) WEIGHTED RANDOM SAMPLER
# --------------------------
sampler = WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(sample_weights),
    replacement=True
)
# Out:
# Klassenhäufigkeiten: [24274  7085  4125]
# Class Weights: [0.18950892 0.35077643 0.45971466]

# %%
import torch
import torch.nn as nn

device = "cuda" if torch.cuda.is_available() else "cpu"


# ============================================================
#   MODEL (DEIN 2-HEAD CNN)
# ============================================================
class ImprovedCNN(nn.Module):
    def __init__(self):
        super().__init__()

        # ---- Block 1 ----
        self.conv1 = nn.Sequential(
            nn.Conv2d(1, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU()
        )
        self.pool1 = nn.MaxPool2d(2)

        # ---- Block 2 ----
        self.conv2 = nn.Sequential(
            nn.Conv2d(32, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU()
        )
        self.pool2 = nn.MaxPool2d(2)

        # ---- Block 3 ----
        self.conv3 = nn.Sequential(
            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU()
        )
        self.pool3 = nn.MaxPool2d(2)

        # ---- Global Average Pooling ----
        self.gap = nn.AdaptiveAvgPool2d((1,1))

        # ---- TWO OUTPUT HEADS ----
        self.dropout = nn.Dropout(0.3)
        self.head_liver = nn.Linear(128, 1)
        self.head_tumor = nn.Linear(128, 1)

    def forward(self, x):
        x = self.pool1(self.conv1(x))
        x = self.pool2(self.conv2(x))
        x = self.pool3(self.conv3(x))

        x = self.gap(x)
        x = x.view(x.size(0), -1)

        x = self.dropout(x)

        out_liver = self.head_liver(x)   # [B,1]
        out_tumor = self.head_tumor(x)   # [B,1]

        return out_liver, out_tumor


model = ImprovedCNN().to(device)



# ============================================================
#   MULTI-LABEL FOCAL LOSS (BCE-VERSION)
# ============================================================
class BCEFocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2.0):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.bce = nn.BCEWithLogitsLoss(reduction="none")

    def forward(self, logits, targets):
        # logits: [B,1]
        # targets: [B,1]
        bce_loss = self.bce(logits, targets)
        pt = torch.exp(-bce_loss)
        loss = self.alpha * (1 - pt)**self.gamma * bce_loss
        return loss.mean()


focal_loss = BCEFocalLoss(alpha=0.25, gamma=2.0)



# ============================================================
#   HEAD-GEWICHTE AUS CSV BERECHNEN
# ============================================================
liver_pos = sum(train_ds.data["liver_visible"] == 1)
liver_neg = sum(train_ds.data["liver_visible"] == 0)
tumor_pos = sum(train_ds.data["lesion_visible"] == 1)
tumor_neg = sum(train_ds.data["lesion_visible"] == 0)

# inverse Frequenz
w_liver = liver_pos / (liver_pos + liver_neg)
w_tumor = tumor_pos / (tumor_pos + tumor_neg)

w_liver = 1.0 / w_liver
w_tumor = 1.0 / w_tumor


w_liver = torch.tensor(w_liver, dtype=torch.float32, device=device)
w_tumor = torch.tensor(w_tumor, dtype=torch.float32, device=device)

print("Liver weight:", w_liver.item())
print("Tumor weight:", w_tumor.item())


# ============================================================
#   OPTIMIZER
# ============================================================
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
# Out:
# Liver weight: 0.6840829849243164
# Tumor weight: 0.8837504386901855

# %%
# ============================
#       DATALOADER
# ============================

batch_size = 128

train_loader = DataLoader(
    dataset=train_ds,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,
    drop_last=True
)


val_loader = DataLoader(
    dataset=val_ds,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,
    drop_last=False
)

test_loader = DataLoader(
    dataset=test_ds,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,
    drop_last=False
)

print("train_loader ready:", len(train_loader))
print("val_loader ready:", len(val_loader))
print("test_loader ready:", len(test_loader))


num_epochs = 15

for epoch in range(num_epochs):

    # -------------------------
    #        TRAINING
    # -------------------------
    model.train()

    for step, (data, targets) in enumerate(train_loader):

        data = data.to(device)
        targets = targets.to(device)

        optimizer.zero_grad()

        # --------- MODEL OUTPUT ---------
        logit_liver, logit_tumor = model(data)

        # --------- TARGET SPLIT ---------
        t_liver = targets[:, 0].unsqueeze(1)   # [B,1]
        t_tumor = targets[:, 1].unsqueeze(1)   # [B,1]

        # --------- LOSS ---------
        loss_liver = w_liver * focal_loss(logit_liver, t_liver)
        loss_tumor = w_tumor * focal_loss(logit_tumor, t_tumor)
        loss = loss_liver + loss_tumor

        loss.backward()
        optimizer.step()

        if step % 50 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}] "
                  f"Step [{step+1}/{len(train_loader)}] "
                  f"Loss: {loss.item():.4f}")

    # -------------------------
    #       VALIDATION
    # -------------------------
    if epoch % 1 == 0:
        model.eval()
        with torch.no_grad():

            losses = []
            batch_sizes = []

            all_preds = []     # predicted 0/1/2
            all_targets = []   # true 0/1/2

            for step, (data, targets) in enumerate(val_loader):
                data = data.to(device)
                targets = targets.to(device)

                # --------- MODEL OUTPUT ---------
                logit_liver, logit_tumor = model(data)

                # --------- TARGET SPLIT ---------
                t_liver = targets[:, 0].unsqueeze(1)
                t_tumor = targets[:, 1].unsqueeze(1)

                # --------- LOSS ---------
                loss_liver = w_liver * focal_loss(logit_liver, t_liver)
                loss_tumor = w_tumor * focal_loss(logit_tumor, t_tumor)
                loss = loss_liver + loss_tumor

                losses.append(loss.item())
                batch_sizes.append(data.size(0))

                # --------- PREDICTIONS ---------
                liver_prob = torch.sigmoid(logit_liver)
                tumor_prob = torch.sigmoid(logit_tumor)

                liver_pred = (liver_prob >= 0.5).long()
                tumor_pred = (tumor_prob >= 0.5).long()

                # --------- Convert to class 0/1/2 ---------
                # Rules:
                # liver=0 → class 0
                # liver=1 & tumor=0 → class 1
                # liver=1 & tumor=1 → class 2
                for lv, tu in zip(liver_pred.cpu().numpy(), tumor_pred.cpu().numpy()):
                    lv = lv[0]
                    tu = tu[0]
                    if lv == 0:
                        all_preds.append(0)
                    elif tu == 0:
                        all_preds.append(1)
                    else:
                        all_preds.append(2)

                # --------- TRUE CLASS ---------
                for lv, tu in zip(t_liver.cpu().numpy(), t_tumor.cpu().numpy()):
                    lv = lv[0]
                    tu = tu[0]
                    if lv == 0:
                        all_targets.append(0)
                    elif tu == 0:
                        all_targets.append(1)
                    else:
                        all_targets.append(2)

        # --------- AVERAGE LOSS ---------
        avg_loss = sum([l * bs for l, bs in zip(losses, batch_sizes)]) / sum(batch_sizes)

        # --------- TOTAL ACC ---------
        import numpy as np
        all_preds_np = np.array(all_preds)
        all_targets_np = np.array(all_targets)
        accuracy = np.mean(all_preds_np == all_targets_np)

        print(f"\nEpoch: {epoch+1}, Validation Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")

        # --------- CLASSWISE ACC ---------
        class_correct = [0,0,0]
        class_total   = [0,0,0]

        for t, p in zip(all_targets_np, all_preds_np):
            class_total[t] += 1
            if t == p:
                class_correct[t] += 1

        print("Classwise Accuracy:")
        for i in range(3):
            if class_total[i] > 0:
                print(f"  Klasse {i}: {class_correct[i] / class_total[i]:.3f}")
            else:
                print(f"  Klasse {i}: ---")

        # --------- CONFUSION MATRIX ---------
        from sklearn.metrics import confusion_matrix
        import seaborn as sns
        import matplotlib.pyplot as plt

        cm = confusion_matrix(all_targets_np, all_preds_np)
        print("\nConfusion Matrix:\n", cm)

        plt.figure(figsize=(6,4))
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
        plt.title("Validation Confusion Matrix")
        plt.xlabel("Predicted")
        plt.ylabel("True")
        plt.show()

        model.train()
# Out:
# train_loader ready: 277
# val_loader ready: 24
# test_loader ready: 24
# Epoch [1/15] Step [1/277] Loss: 0.0378
# Epoch [1/15] Step [51/277] Loss: 0.0305
# Epoch [1/15] Step [101/277] Loss: 0.0261
# Epoch [1/15] Step [151/277] Loss: 0.0263
# Epoch [1/15] Step [201/277] Loss: 0.0255
# Epoch [1/15] Step [251/277] Loss: 0.0247
#
# Epoch: 1, Validation Loss: 0.0368, Accuracy: 0.6295
# Classwise Accuracy:
#   Klasse 0: 0.748
#   Klasse 1: 0.579
#   Klasse 2: 0.047
#
# Confusion Matrix:
#  [[1586  534    0]
#  [   6  309  219]
#  [   3  364   18]]
# Epoch [2/15] Step [1/277] Loss: 0.0277
# Epoch [2/15] Step [51/277] Loss: 0.0222
# Epoch [2/15] Step [101/277] Loss: 0.0249
# Epoch [2/15] Step [151/277] Loss: 0.0301
# Epoch [2/15] Step [201/277] Loss: 0.0267
# Epoch [2/15] Step [251/277] Loss: 0.0258
#
# Epoch: 2, Validation Loss: 0.0332, Accuracy: 0.7861
# Classwise Accuracy:
#   Klasse 0: 0.945
#   Klasse 1: 0.723
#   Klasse 2: 0.000
#
# Confusion Matrix:
#  [[2003  117    0]
#  [ 103  386   45]
#  [ 131  254    0]]
# Epoch [3/15] Step [1/277] Loss: 0.0250
# Epoch [3/15] Step [51/277] Loss: 0.0268
# Epoch [3/15] Step [101/277] Loss: 0.0227
# Epoch [3/15] Step [151/277] Loss: 0.0228
# Epoch [3/15] Step [201/277] Loss: 0.0274
# Epoch [3/15] Step [251/277] Loss: 0.0326
#
# Epoch: 3, Validation Loss: 0.0282, Accuracy: 0.7753
# Classwise Accuracy:
#   Klasse 0: 0.967
#   Klasse 1: 0.571
#   Klasse 2: 0.000
#
# Confusion Matrix:
#  [[2051   69    0]
#  [ 167  305   62]
#  [  95  290    0]]
# Epoch [4/15] Step [1/277] Loss: 0.0209
# Epoch [4/15] Step [51/277] Loss: 0.0221
# Epoch [4/15] Step [101/277] Loss: 0.0255
# Epoch [4/15] Step [151/277] Loss: 0.0195
# Epoch [4/15] Step [201/277] Loss: 0.0232
# Epoch [4/15] Step [251/277] Loss: 0.0247
#
# Epoch: 4, Validation Loss: 0.0299, Accuracy: 0.7647
# Classwise Accuracy:
#   Klasse 0: 0.959
#   Klasse 1: 0.545
#   Klasse 2: 0.000
#
# Confusion Matrix:
#  [[2033   87    0]
#  [ 172  291   71]
#  [  78  307    0]]
# Epoch [5/15] Step [1/277] Loss: 0.0236
# Epoch [5/15] Step [51/277] Loss: 0.0232
# Epoch [5/15] Step [101/277] Loss: 0.0181
# Epoch [5/15] Step [151/277] Loss: 0.0223
# Epoch [5/15] Step [201/277] Loss: 0.0241
# Epoch [5/15] Step [251/277] Loss: 0.0170
#
# Epoch: 5, Validation Loss: 0.0270, Accuracy: 0.7279
# Classwise Accuracy:
#   Klasse 0: 0.926
#   Klasse 1: 0.427
#   Klasse 2: 0.052
#
# Confusion Matrix:
#  [[1964  156    0]
#  [ 122  228  184]
#  [  22  343   20]]
# Epoch [6/15] Step [1/277] Loss: 0.0193
# Epoch [6/15] Step [51/277] Loss: 0.0189
# Epoch [6/15] Step [101/277] Loss: 0.0230
# Epoch [6/15] Step [151/277] Loss: 0.0218
# Epoch [6/15] Step [201/277] Loss: 0.0243
# Epoch [6/15] Step [251/277] Loss: 0.0194
#
# Epoch: 6, Validation Loss: 0.0311, Accuracy: 0.7644
# Classwise Accuracy:
#   Klasse 0: 0.929
#   Klasse 1: 0.625
#   Klasse 2: 0.049
#
# Confusion Matrix:
#  [[1970  150    0]
#  [  63  334  137]
#  [  23  343   19]]
# Epoch [7/15] Step [1/277] Loss: 0.0177
# Epoch [7/15] Step [51/277] Loss: 0.0189
# Epoch [7/15] Step [101/277] Loss: 0.0204
# Epoch [7/15] Step [151/277] Loss: 0.0233
# Epoch [7/15] Step [201/277] Loss: 0.0229
# Epoch [7/15] Step [251/277] Loss: 0.0189
#
# Epoch: 7, Validation Loss: 0.0296, Accuracy: 0.7292
# Classwise Accuracy:
#   Klasse 0: 0.879
#   Klasse 1: 0.526
#   Klasse 2: 0.187
#
# Confusion Matrix:
#  [[1863  257    0]
#  [  50  281  203]
#  [   3  310   72]]
# Epoch [8/15] Step [1/277] Loss: 0.0188
# Epoch [8/15] Step [51/277] Loss: 0.0238
# Epoch [8/15] Step [101/277] Loss: 0.0195
# Epoch [8/15] Step [151/277] Loss: 0.0186
# Epoch [8/15] Step [201/277] Loss: 0.0183
# Epoch [8/15] Step [251/277] Loss: 0.0221
#
# Epoch: 8, Validation Loss: 0.0306, Accuracy: 0.7703
# Classwise Accuracy:
#   Klasse 0: 0.977
#   Klasse 1: 0.504
#   Klasse 2: 0.000
#
# Confusion Matrix:
#  [[2072   48    0]
#  [ 204  269   61]
#  [ 132  253    0]]
# Epoch [9/15] Step [1/277] Loss: 0.0210
# Epoch [9/15] Step [51/277] Loss: 0.0188
# Epoch [9/15] Step [101/277] Loss: 0.0191
# Epoch [9/15] Step [151/277] Loss: 0.0194
# Epoch [9/15] Step [201/277] Loss: 0.0210
# Epoch [9/15] Step [251/277] Loss: 0.0206
#
# Epoch: 9, Validation Loss: 0.0305, Accuracy: 0.7697
# Classwise Accuracy:
#   Klasse 0: 0.976
#   Klasse 1: 0.506
#   Klasse 2: 0.000
#
# Confusion Matrix:
#  [[2069   51    0]
#  [ 224  270   40]
#  [  60  325    0]]
# Epoch [10/15] Step [1/277] Loss: 0.0170
# Epoch [10/15] Step [51/277] Loss: 0.0180
# Epoch [10/15] Step [101/277] Loss: 0.0181
# Epoch [10/15] Step [151/277] Loss: 0.0171
# Epoch [10/15] Step [201/277] Loss: 0.0235
# Epoch [10/15] Step [251/277] Loss: 0.0171
#
# Epoch: 10, Validation Loss: 0.0301, Accuracy: 0.7226
# Classwise Accuracy:
#   Klasse 0: 0.819
#   Klasse 1: 0.537
#   Klasse 2: 0.449
#
# Confusion Matrix:
#  [[1736  384    0]
#  [  19  287  228]
#  [   0  212  173]]
# Epoch [11/15] Step [1/277] Loss: 0.0147
# Epoch [11/15] Step [51/277] Loss: 0.0144
# Epoch [11/15] Step [101/277] Loss: 0.0228
# Epoch [11/15] Step [151/277] Loss: 0.0195
# Epoch [11/15] Step [201/277] Loss: 0.0166
# Epoch [11/15] Step [251/277] Loss: 0.0179
#
# Epoch: 11, Validation Loss: 0.0268, Accuracy: 0.7410
# Classwise Accuracy:
#   Klasse 0: 0.933
#   Klasse 1: 0.496
#   Klasse 2: 0.026
#
# Confusion Matrix:
#  [[1977  143    0]
#  [ 138  265  131]
#  [  27  348   10]]
# Epoch [12/15] Step [1/277] Loss: 0.0157
# Epoch [12/15] Step [51/277] Loss: 0.0163
# Epoch [12/15] Step [101/277] Loss: 0.0226
# Epoch [12/15] Step [151/277] Loss: 0.0220
# Epoch [12/15] Step [201/277] Loss: 0.0158
# Epoch [12/15] Step [251/277] Loss: 0.0195
#
# Epoch: 12, Validation Loss: 0.0244, Accuracy: 0.7631
# Classwise Accuracy:
#   Klasse 0: 0.916
#   Klasse 1: 0.483
#   Klasse 2: 0.309
#
# Confusion Matrix:
#  [[1942  178    0]
#  [ 108  258  168]
#  [   3  263  119]]
# Epoch [13/15] Step [1/277] Loss: 0.0189
# Epoch [13/15] Step [51/277] Loss: 0.0177
# Epoch [13/15] Step [101/277] Loss: 0.0164
# Epoch [13/15] Step [151/277] Loss: 0.0165
# Epoch [13/15] Step [201/277] Loss: 0.0210
# Epoch [13/15] Step [251/277] Loss: 0.0192
#
# Epoch: 13, Validation Loss: 0.0392, Accuracy: 0.7881
# Classwise Accuracy:
#   Klasse 0: 0.986
#   Klasse 1: 0.569
#   Klasse 2: 0.000
#
# Confusion Matrix:
#  [[2091   29    0]
#  [ 187  304   43]
#  [  93  292    0]]
# Epoch [14/15] Step [1/277] Loss: 0.0166
# Epoch [14/15] Step [51/277] Loss: 0.0171
# Epoch [14/15] Step [101/277] Loss: 0.0182
# Epoch [14/15] Step [151/277] Loss: 0.0117
# Epoch [14/15] Step [201/277] Loss: 0.0186
# Epoch [14/15] Step [251/277] Loss: 0.0188
#
# Epoch: 14, Validation Loss: 0.0275, Accuracy: 0.7838
# Classwise Accuracy:
#   Klasse 0: 0.957
#   Klasse 1: 0.661
#   Klasse 2: 0.000
#
# Confusion Matrix:
#  [[2029   91    0]
#  [ 142  353   39]
#  [  31  354    0]]
# Epoch [15/15] Step [1/277] Loss: 0.0111
# Epoch [15/15] Step [51/277] Loss: 0.0200
# Epoch [15/15] Step [101/277] Loss: 0.0172
# Epoch [15/15] Step [151/277] Loss: 0.0182
# Epoch [15/15] Step [201/277] Loss: 0.0201
# Epoch [15/15] Step [251/277] Loss: 0.0160
#
# Epoch: 15, Validation Loss: 0.0286, Accuracy: 0.7499
# Classwise Accuracy:
#   Klasse 0: 0.891
#   Klasse 1: 0.639
#   Klasse 2: 0.130
#
# Confusion Matrix:
#  [[1888  232    0]
#  [  50  341  143]
#  [   0  335   50]]

# %%
# ============================
#          TEST PHASE
# ============================

model.eval()
with torch.no_grad():

    all_preds = []     # predicted class 0/1/2
    all_targets = []   # true class 0/1/2

    losses = []
    batch_sizes = []

    for data, targets in test_loader:

        data = data.to(device)
        targets = targets.to(device)

        # --------- MODEL OUTPUT ---------
        logit_liver, logit_tumor = model(data)

        # --------- TARGET SPLIT ---------
        t_liver = targets[:, 0].unsqueeze(1)
        t_tumor = targets[:, 1].unsqueeze(1)

        # --------- LOSS ---------
        loss_liver = w_liver * focal_loss(logit_liver, t_liver)
        loss_tumor = w_tumor * focal_loss(logit_tumor, t_tumor)
        loss = loss_liver + loss_tumor

        losses.append(loss.item())
        batch_sizes.append(data.size(0))

        # --------- PROBABILITIES ---------
        liver_prob = torch.sigmoid(logit_liver)
        tumor_prob = torch.sigmoid(logit_tumor)

        liver_pred = (liver_prob >= 0.5).long()
        tumor_pred = (tumor_prob >= 0.5).long()

        # --------- PRED → CLASS 0/1/2 ---------
        for lv, tu in zip(liver_pred.cpu().numpy(), tumor_pred.cpu().numpy()):
            lv = lv[0]
            tu = tu[0]
            if lv == 0:
                all_preds.append(0)
            elif tu == 0:
                all_preds.append(1)
            else:
                all_preds.append(2)

        # --------- TRUE → CLASS 0/1/2 ---------
        for lv, tu in zip(t_liver.cpu().numpy(), t_tumor.cpu().numpy()):
            lv = lv[0]
            tu = tu[0]
            if lv == 0:
                all_targets.append(0)
            elif tu == 0:
                all_targets.append(1)
            else:
                all_targets.append(2)


# ============================
#     METRICS & CONFUSION
# ============================

import numpy as np

all_preds_np = np.array(all_preds)
all_targets_np = np.array(all_targets)

# --------- AVG LOSS ---------
avg_loss = sum([l * bs for l, bs in zip(losses, batch_sizes)]) / sum(batch_sizes)

# --------- TOTAL ACC ---------
accuracy = np.mean(all_preds_np == all_targets_np)

print(f"\nTEST RESULTS:")
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# --------- CLASSWISE ACC ---------
class_correct = [0,0,0]
class_total   = [0,0,0]

for t, p in zip(all_targets_np, all_preds_np):
    class_total[t] += 1
    if t == p:
        class_correct[t] += 1

print("\nClasswise Test Accuracy:")
for i in range(3):
    if class_total[i] > 0:
        print(f"  Klasse {i}: {class_correct[i] / class_total[i]:.3f}")
    else:
        print(f"  Klasse {i}: ---")

# --------- CONFUSION MATRIX ---------
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(all_targets_np, all_preds_np)
print("\nConfusion Matrix:\n", cm)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Test Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# TEST RESULTS:
# Test Loss: 0.0225
# Test Accuracy: 0.8199
#
# Classwise Test Accuracy:
#   Klasse 0: 0.876
#   Klasse 1: 0.853
#   Klasse 2: 0.457
#
# Confusion Matrix:
#  [[1611  227    0]
#  [  43  714   80]
#  [   4  193  166]]
